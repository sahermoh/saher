# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
#tramform the image to ttf>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
img = cv2.imread('tools.pgm',0)
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()




# create a mask first, ideal  low pass filter  

rows, cols = img.shape
crow,ccol = rows/2 , cols/2
r=20
h_Filter_Low_Pass = np.zeros(img.size, img.dtype).reshape(img.shape)
mask = np.zeros((rows,cols,2),np.uint8)
for icounter in range(1, height):
    for jcounter in range(1, width):
        if ((icounter - crow)**2 + (jcounter - ccol)**2) < r**2:
            mask[icounter, jcounter] = 1
            h_Filter_Low_Pass[icounter, jcounter] = 1

            
plt.imshow(h_Filter_Low_Pass, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.show() 
            

# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
#tramform the image to ttf>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
img = cv2.imread('tools.pgm',0)
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()


import math


# create a mask first, gaussian low pass filter  

rows, cols = img.shape
w=rows,cols,2
mask = np.zeros(w)

crows=rows/2
ccol=cols/2
r=30
ss = np.zeros(img.size).reshape(img.shape)
for i in range(1, rows):
    for j in range(1, cols):
        d=((i - crows)**2) + ((j - ccol)**2)
        f=2*(r**2)
        c =-d/f
        l=math.exp(c)
        ss[i,j]=l
        mask[i,j]=l
        
        
            
plt.imshow(ss, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.show() 


# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# read image
# get fft of image --> f
# crate mask
# multiply f with mask --> g
# get inverse of g

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
#tramform the image to ttf>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
img = cv2.imread('tools.pgm',0)
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()


import math


# create a mask first, ideal  low pass filter  

rows, cols = img.shape
l=rows,cols,2
mask = np.zeros(l)

crows=rows/2
ccol=cols/2
r=20
n=3
ss = np.zeros(img.size).reshape(img.shape)
for i in range(1, rows):
    for j in range(1, cols):
        d=(i - crows)**2 + (j - ccol)**2
        dd=d**0.5
        m=(dd/r)
        p=m**2
        f=1+p
        c=1/f
        ss[i,j]=float (c)       

        mask[i,j]=c
            
plt.imshow(ss, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.show() 


# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
#tramform the image to ttf>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
img = cv2.imread('oso.jpg',0)
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

import math


# create a mask first, gau  low pass filter  

rows, cols = img.shape
crow,ccol = rows/2 , cols/2
mask = np.zeros((rows,cols,2),np.uint8)

lp = np.zeros(img.size).reshape(img.shape)
r=0.2

for i in range(1, rows):
    for j in range(1, cols):
        if (r-crow)**2 <=((i - crow)**2 + (j - ccol)**2) < (r+crow)**2:
            lp[i,j]=1
            mask[i,j]=1


k=cv2.bitwise_not(lp)
kk= cv2.bitwise_not(mask)


plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Filter'), 
plt.xticks(20), 
plt.yticks([])
plt.show()




plt.imshow(k, cmap = 'gray')
plt.title('Filter'), plt.xticks([]), plt.yticks([])
plt.show()


# apply mask and inverse FT
fshift = dft_shift*kk
f_ishift = np.fft.ifftshift(fshift)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-8eb1be78de28> in <module>()
#      39 plt.imshow(magnitude_spectrum, cmap = 'gray')
#      40 plt.title('Filter'),
# ---> 41 plt.xticks(20),
#      42 plt.yticks([])
#      43 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xticks(*args, **kwargs)
#    1696         labels = ax.get_xticklabels()
#    1697     elif len(args)==1:
# -> 1698         locs = ax.set_xticks(args[0])
#    1699         labels = ax.get_xticklabels()
#    1700     elif len(args)==2:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xticks(self, ticks, minor)
#    2976         ACCEPTS: sequence of floats
#    2977         """
# -> 2978         ret = self.xaxis.set_ticks(ticks, minor=minor)
#    2979         self.stale = True
#    2980         return ret
#
# ...
