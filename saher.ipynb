# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('swan.pgm',0)



ret,l =cv2.threshold(img1,0,255,cv2.THRESH_OTSU)


th2 = cv2.adaptiveThreshold(img1,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)#adaptive threshold
plt.imshow(img1,'gray')
plt.title("img1")
plt.xticks([]),plt.yticks([])
plt.show()



plt.hist(img1.ravel(),256,[0,256]); plt.show()



plt.imshow(l,'gray')
plt.title("otsu threshold")
plt.xticks([]),plt.yticks([])
plt.show()

plt.imshow(th2,'gray')
plt.title("adaptive threshold")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # analaysis of histogram
#
#
# from the histogram of the grayscale image we are knowing : 1.this image is high contract because the intensity pixel values are distributed along the histogram (between 0 and 255) 2.It is stretched then the contract is good

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img2 = cv2.imread('flower.pgm',0)


plt.hist(img2.ravel(),256,[0,256]); plt.show()#histogram of the image 


equ = cv2.equalizeHist(img2)
result = np.hstack((img2,equ))#equalization if the histogram

plt.imshow(result,'gray')
plt.title("image equalize")
plt.xticks([]),plt.yticks([])
plt.show()



ret,l2 =cv2.threshold(equ,0,255,cv2.THRESH_OTSU)#ousto of the image 

th3= cv2.adaptiveThreshold(equ,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)#adaptive threshold












plt.imshow(l2,'gray')
plt.title("otsu threshold")
plt.xticks([]),plt.yticks([])
plt.show()

plt.imshow(th3,'gray')
plt.title("adaptive threshold")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # analysis
# from the histogram of the grayscale image we are knowing : 1.this image is low contract because  pixel values are not distributed along the histogram 2.It is  not stretched then the contract is bad

# %%
img3 = cv2.imread('tools.pgm',0)

plt.hist(img3.ravel(),256,[0,256]); plt.show()#histogram of the orginal image 


equ2 = cv2.equalizeHist(img3)
resultt = np.hstack((img3,equ2))#equalization of the histogram

plt.imshow(resultt,'gray')
plt.title("image equalize")
plt.xticks([]),plt.yticks([])
plt.show()


ret,l3 =cv2.threshold(equ2,0,255,cv2.THRESH_OTSU)#outs on the image 


th4 = cv2.adaptiveThreshold(equ2,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)#adaptive threshold


plt.imshow(l3,'gray')
plt.title("otsu threshold")
plt.xticks([]),plt.yticks([])
plt.show()


plt.imshow(th4,'gray')
plt.title("adaptive threshold")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # analysis
#
# from the histogram of the grayscale image we are knowing : 1.this image is low contract because  pixel values are  does not distributed along the histogram 2.It is not stretched then the contract is not good and need to inhansment it

# %% [markdown]
# # how otsu work
#
# //global(ياخذ قيمة واحد للثريشولد بناء على رسمة الهستوقرام)
#
# //يعمل globaly عندما يأخذ قيمة الحد
#
#
# //Operates directly on the gray level  histogram  so it’s fast (once the histogram is computed)
#
# //Assumes stationary statistics, but can be modified to be locally adaptive.
#
# //idea: Find the threshold that minimizes the weighted within-class variance.
#
# //The aim is to find the threshold value where the sum of foreground and background spreads is at its minimum.
#
#
#
#
# ///The algorithm assumes that the image contains two classes of pixels following histogram (foreground pixels and background pixels), it then calculates the optimum threshold separating the two classes so that their combined spread (intra-class variance).
#
# /// Consequently, Otsu's method is roughly a one-dimensional
#
#
#
#
# /// Algorithm
# 1.Compute histogram and probabilities of each intensity level
# 2.Set up initial ω i ( 0 )  μ i ( 0 )
# 3.Step through all possible thresholds t = 1 , …  maximum intensity
# Update ω i  and μ i
# Compute σ b 2 ( t )
# 4.Desired threshold corresponds to the maximum σ b 2 ( t )
#
#
# /// example : http://www.labbookpages.co.uk/software/imgProc/otsuThreshold.html

# %% [markdown]
# # how adaptive work
#
# ///when we use adaptive
# in global threshold we take a global value as threshold value. But it may not be good in all the conditions where image has different lighting conditions in different areas.
#
# //it is not global
#
# //Adaptive thresholding typically takes a grayscale or color image as input and, in the simplest implementation, outputs a binary image representing the segmentation. For each pixel in the image, a threshold has to be calculated. If the pixel value is below the threshold it is set to the background value, otherwise it assumes the foreground value
#
# ///what is the abaptive and how work ?
# In this, the algorithm calculate the threshold for a small regions of the image. So we get different thresholds for different regions of the same image and it gives us better results for images with varying illumination.
#
# // it used the neighborhood tequniqe to take many threshold values on the same img
#
# //two method :
# !!!.cv2.ADAPTIVE_THRESH_MEAN_C : threshold value is the mean of neighbourhood area.
# !!!.cv2.ADAPTIVE_THRESH_GAUSSIAN_C : threshold value is the weighted sum of neighbourhood values where weights are a gaussian window.

# %% [markdown]
# # referances
# a. Davies Machine Vision: Theory, Algorithms and Practicalities, Academic Press, 1990, pp 91 - 96.
#
# b. Gonzales and R. Woods Digital Image Processing, Addison-Wesley Publishing Company, 1992, pp 443 - 452.
#
# c.opencv toutorial
